# %% [markdown]
# # Problemas de ordenação de linhas de código (problemas de Parsons)
#
# Neste caderno, você vai praticar um tipo de exercício denominado _problemas de Parsons_ em que você precisa colocar um conjunto de linhas de código em ordem para obter um programa funcional. Você receberá uma descrição do objetivo do programa. Em seguida, o caderno trará uma célula de código. Você deve executar a célula de código para visualizar o exercício. Note que nestes exercícios você deve acertar a **não somente a ordem de execução** das linhas mas também seu **alinhamento** (indentação).
#
# **Exemplo**. Execute a célula abaixo para visualizar o exercício de ordenação. O objetivo do programa é imprimir o texto "ABC". Arraste as linhas de código da esquerda para o quadro da direita para montar a sua solução. Quando tiver terminado, clique no botão "Get feedback". Caso sua solução esteja correta, as linhas de código mudarão para a cor verde. Do contrário, as linhas posicionada incorretamente aparecerão em vermelhor. Caso precise recomeçar do início, clique no botão "New instance".

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/59aa3730b51240079f00c61978399727', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/59aa3730b51240079f00c61978399727"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Exercício 1
#
# O pH de uma solução é uma medida de sua concentração de íons de hidrogênio. Uma solução é considerada _ácida_ se o seu pH estiver no intervalo $[0, 7[$. Uma solução é considerada _básica_ se o seu pH estiver no intervalo $]7, 14]$. Uma solução é considerada neutra se o seu pH for igual a 7. No problema abaixo, você deve ordenar as linhas de modo que o programa:
# - receba um valor de pH digitado pelo usuário.
# - imprima uma mensagem dizendo se a solução é _ácida_, _neutra_ ou _básica_.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/ff17cc8a5fa443e7910da7ffcbe85cbd', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/ff17cc8a5fa443e7910da7ffcbe85cbd"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Exercício 2
#
# Uma empresa de comércio eletrônico implantou a seguinte política de descontos:
# - Se o valor total dos itens é inferior a 200 reais, não é aplicado nenhum desconto.
# - Se o valor total dos itens é superior a 200 reais, aplica-se um desconto de 5% (cinco porcento) sobre o _excedente_, isto é, o desconto é aplicado somente ao valor superior a 200 reais. Por exemplo, uma compra de 300 reais é reduzida para 295 reais após o desconto.
#
# No problema abaixo, você deve ordenar as linhas de código de modo que o programa receba o valor total de itens e aplique o desconto, caso necessário. O programa deve imprimir então o valor total da compra.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/a3c12d5249c04f5eb790099342e2cd6f', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/a3c12d5249c04f5eb790099342e2cd6f"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
