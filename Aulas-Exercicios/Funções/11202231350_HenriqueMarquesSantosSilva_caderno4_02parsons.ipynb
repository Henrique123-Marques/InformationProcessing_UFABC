# %% [markdown]
# # Problemas de ordenação de linhas de código (problemas de Parsons)
#
# Neste caderno, você vai praticar um tipo de exercício denominado _problemas de Parsons_ em que você precisa colocar um conjunto de linhas de código em ordem para obter um programa funcional. Você receberá uma descrição do objetivo do programa. Em seguida, o caderno trará uma célula de código. Você deve executar a célula de código para visualizar o exercício. Note que nestes exercícios você deve acertar a **não somente a ordem de execução** das linhas mas também seu **alinhamento** (indentação).

# %% [markdown]
# ## Exercício 1
#
# A função ``decora`` recebe um _string_ ``texto``, um _string_ ``d`` e um número inteiro positivo ``n``. Em seguida, a função devolve um novo _string_ formado por n repetições de ``d``, seguido por ``texto`` seguido por mais n repetições de ``d``. Por exemplo, ``decora("UFABC", "*", 3)`` produz o _string_ ``***UFABC***``. Nota: em Python, a operação ``um_string*um_natural`` produz o _string_ ``um_string`` repetido ``um_natural`` vezes. Por exemplo, ``"ab"*3`` produz ``"ababab"``.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/d86d84b5706e4cc6b27b611856141526', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/d86d84b5706e4cc6b27b611856141526"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Exercício 2
#
# Depois de criar a função ``decora`` acima, o autor do código pensou que um usuário poderia se confundir e passar um valor negativo no lugar de ``n``. Para lidar com essa possibilidade, o autor decidiu que a função deveria devolver um _string_ vazio nesse caso (ou seja, ""). Ele então criou a função ``decora2`` abaixo:

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/fda699d0ab764ca2964849af309c5225', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/fda699d0ab764ca2964849af309c5225"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Exercício 3
#
# A função ``abs_diferenca`` calcula o valor absoluto da diferença entre dois números. Por exemplo, ``abs_diferenca(2, 8)`` devolve 6 e ``abs_diferenca(1, 3)`` devolve 2.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/b27c0e47a864495d9407b6d9c530c4f4', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/b27c0e47a864495d9407b6d9c530c4f4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Exercício 4
#
# Um empresário de duplas musicais decidiu que um nome da dupla deveria ser formatado de maneira que o menor nome apareça em primeiro lugar, como em "Tom & Jerry" ou "Leandro & Leonardo". Para isso, ele criou a função ``formata_dupla`` abaixo. Dica: em Python a função ``len`` devolve o tamanho de um _string_. Por exemplo, ``len("UFABC")`` devolve 5, e ``len("Santo André)`` devolve 11.

# %%
from IPython.display import IFrame
IFrame('https://parsons.problemsolving.io/puzzle/9baa79758e414c2f84f1c61d3f58a914', width=1000, height=400)
# Out:
#         <iframe
#             width="1000"
#             height="400"
#             src="https://parsons.problemsolving.io/puzzle/9baa79758e414c2f84f1c61d3f58a914"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
